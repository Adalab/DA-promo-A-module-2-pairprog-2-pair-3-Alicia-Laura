# %%
import pandas as pd
import mysql.connector

# %%
df_attacks = pd.read_csv('attacks_limpieza_completa.csv', index_col=0)
df_attacks.head(2)
# Out:
#    year        type country   age     species_ fecha_limpia fatal sex  \
# 0  2018     Boating     usa  57.0  White shark          Jun     N   F
# 1  2018  Unprovoked     usa  11.0  Unespecific          Jun     N   F
#
#     latitud    longitud  ... fatal_N  fatal_Unknown  fatal_Y  fatal_N.1  \
# 0  39.78373 -100.445882  ...       1              0        0          1
# 1  39.78373 -100.445882  ...       1              0        0          1
#
#    fatal_Unknown.1  fatal_Y.1  species_.1  fecha_limpia.1  type.1  age_NORM
# 0                0          0           4               7       1  9.116327
# 1                0          0           3               7       7  3.804860
#
# [2 rows x 21 columns]

# %%
df_attacks = pd.read_csv('attacks_limpieza_completa.csv', index_col=0)
df_attacks.head(2)
# Out:
#    year        type country   age     species_ fecha_limpia fatal sex  \
# 0  2018     Boating     usa  57.0  White shark          Jun     N   F
# 1  2018  Unprovoked     usa  11.0  Unespecific          Jun     N   F
#
#     latitud    longitud  ... fatal_N  fatal_Unknown  fatal_Y  fatal_N.1  \
# 0  39.78373 -100.445882  ...       1              0        0          1
# 1  39.78373 -100.445882  ...       1              0        0          1
#
#    fatal_Unknown.1  fatal_Y.1  species_.1  fecha_limpia.1  type.1  age_NORM
# 0                0          0           4               7       1  9.116327
# 1                0          0           3               7       7  3.804860
#
# [2 rows x 21 columns]

# %%
df_clima = pd.read_csv('datos_clima_limpio.csv', index_col=0)
df_clima.head(2)
# Out:
#    rh_950mb  rh_900mb  rh_850mb  rh_800mb  rh_750mb  rh_700mb  rh_650mb  \
# 0         4         3         2         0         2         4         5
# 1         5         3         2         0         3         4         4
#
#    rh_600mb  rh_550mb  rh_500mb  ...  temp2m  lifted_index  rh2m  \
# 0         6         7         3  ...      22             2     8
# 1         7        11         2  ...      22             2     6
#
#    msl_pressure  prec_type  prec_amount  snow_depth  wind10m.direction  \
# 0          1018       none            0           0                225
# 1          1021       none            0           0                250
#
#    wind10m.speed  country
# 0              2      usa
# 1              2      usa
#
# [2 rows x 50 columns]

# %% [markdown]
# Cread la BBDD con el nombre de tiburones.

# %%
def crear_bbdd(nombre_bbdd):

    mydb = mysql.connector.connect(
      host="localhost",
      user="root",
      password="AlumnaAdalab" 
    )
    print("Conexión realizada con éxito")
    
    mycursor = mydb.cursor()

    try:
        mycursor.execute(f"CREATE DATABASE IF NOT EXISTS {nombre_bbdd};")
        print(mycursor)
    except mysql.connector.Error as err:
        print(err)
        print("Error Code:", err.errno)
        print("SQLSTATE", err.sqlstate)
        print("Message", err.msg)

# %% [markdown]
# - Llamamos a la función con el nombre de nuestra BBDD y observamos que se ha creado.

# %%
mydb = crear_bbdd("tiburones")
# Out:
# Conexión realizada con éxito
# CMySQLCursor: CREATE DATABASE IF NOT EXISTS tiburones;

# %% [markdown]
# Cread las tablas de la BBDD:
# - Tabla ataques
# - Tabla clima

# %%
def crear_insertar_tabla(nombre_bbdd, contraseña, query):
    # nos conectamsos con el servidor usando el conector de sql
    cnx = mysql.connector.connect(user='root', password=f"{contraseña}",
                                     host='127.0.0.1', database=f"{nombre_bbdd}")
    # iniciamos el cursor
    mycursor = cnx.cursor()
    
    # intentamos hacer la query
    try: 
        mycursor.execute(query)
        cnx.commit() 
    # en caso de que podamos ejecutar la query devuelvenos un error para saber en que nos estamos equivocando
    except mysql.connector.Error as err:
        print(err)
        print("Error Code:", err.errno)
        print("SQLSTATE", err.sqlstate)
        print("Message", err.msg)

# %%
df_attacks.head(2)
# Out:
#    year        type country   age     species_ fecha_limpia fatal sex  \
# 0  2018     Boating     usa  57.0  White shark          Jun     N   F
# 1  2018  Unprovoked     usa  11.0  Unespecific          Jun     N   F
#
#     latitud    longitud  ... fatal_N  fatal_Unknown  fatal_Y  fatal_N.1  \
# 0  39.78373 -100.445882  ...       1              0        0          1
# 1  39.78373 -100.445882  ...       1              0        0          1
#
#    fatal_Unknown.1  fatal_Y.1  species_.1  fecha_limpia.1  type.1  age_NORM
# 0                0          0           4               7       1  9.116327
# 1                0          0           3               7       7  3.804860
#
# [2 rows x 21 columns]

# %%
tabla_ataques = '''
CREATE TABLE IF NOT EXISTS `tiburones`.`ataques`(
 indice INT NOT NULL AUTO_INCREMENT,
 year INT NOT NULL,
 type VARCHAR(255) NOT NULL,
 country VARCHAR(255) NOT NULL,
 species_ VARCHAR(255) NOT NULL,
 fecha_limpia VARCHAR(255) NOT NULL,
 fatal VARCHAR(255) NOT NULL,
 sex VARCHAR(255) NOT NULL,
 latitud FLOAT NOT NULL,
 longitud FLOAT NOT NULL,
 age_NORM FLOAT NOT NULL,
 PRIMARY KEY (`indice`))
ENGINE = InnoDB;
'''

# %%
df_clima.columns
# Out:
# Index(['rh_950mb', 'rh_900mb', 'rh_850mb', 'rh_800mb', 'rh_750mb', 'rh_700mb',
#        'rh_650mb', 'rh_600mb', 'rh_550mb', 'rh_500mb', 'rh_450mb', 'rh_400mb',
#        'rh_350mb', 'rh_300mb', 'rh_250mb', 'rh_200mb', 'wind_950mb',
#        'wind_900mb', 'wind_850mb', 'wind_800mb', 'wind_750mb', 'wind_700mb',
#        'wind_650mb', 'wind_600mb', 'wind_550mb', 'wind_500mb', 'wind_450mb',
#        'wind_400mb', 'wind_350mb', 'wind_300mb', 'wind_250mb', 'wind_200mb',
#        'index', 'timepoint', 'cloudcover', 'highcloud', 'midcloud', 'lowcloud',
#        'rh_profile', 'wind_profile', 'temp2m', 'lifted_index', 'rh2m',
#        'msl_pressure', 'prec_type', 'prec_amount', 'snow_depth',
#        'wind10m.direction', 'wind10m.speed', 'country'],
#       dtype='object')

# %%
tabla_clima = '''
CREATE TABLE IF NOT EXISTS `tiburones`.`clima`(
 indice INT NOT NULL AUTO_INCREMENT,
 timepoint INT NOT NULL,
 cloudcover INT NOT NULL,
 temp2m INT NOT NULL,
 msl_pressure INT NOT NULL,
 `wind10m.direction` INT NOT NULL,
 `wind10m.speed` INT NOT NULL,
 pais VARCHAR(255) NOT NULL,
 rh_950mb INT NOT NULL,
 wind_900mb INT NOT NULL,
 PRIMARY KEY (`indice`))
ENGINE = InnoDB;
'''

# %% [markdown]
# Hemos elegido solo las columnas 'rh_950m' y 'wind_900mb' como representación de las demás, porque elegir todas hubiera sido demasiado. Solo queriamos ver como introducir datos en la BBDD.

# %% [markdown]
# - Creamos las tablas

# %%
crear_insertar_tabla("tiburones","AlumnaAdalab", tabla_ataques)

# %%
crear_insertar_tabla("tiburones","AlumnaAdalab", tabla_clima)

# %% [markdown]
# BONUS Insertar los datos en las tablas.
# 📌 Nota Esta parte del pair es optativa y no será considerada para la evaluación

# %%
df_attacks.columns
# Out:
# Index(['year', 'type', 'country', 'age', 'species_', 'fecha_limpia', 'fatal',
#        'sex', 'latitud', 'longitud', 'country2', 'fatal_N', 'fatal_Unknown',
#        'fatal_Y', 'fatal_N.1', 'fatal_Unknown.1', 'fatal_Y.1', 'species_.1',
#        'fecha_limpia.1', 'type.1', 'age_NORM'],
#       dtype='object')

# %%
for indice, fila in df_attacks.iterrows():
    query_ataques = f"""
            INSERT INTO ataques (year, type, country, species_, fecha_limpia, fatal, sex, latitud, longitud, age_NORM)
            VALUES ({fila["year"]}, "{fila['type']}", "{fila["country"]}","{fila["species_"]}", "{fila["fecha_limpia"]}","{fila["fatal"]}","{fila["sex"]}",{fila["latitud"]},{fila["longitud"]},{fila["age_NORM"]});
            """
    crear_insertar_tabla("tiburones", "AlumnaAdalab", query_ataques)
# Out:
# 1406 (22001): Data too long for column 'fatal' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'fatal' at row 1
# 1406 (22001): Data too long for column 'fatal' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'fatal' at row 1
# 1406 (22001): Data too long for column 'fatal' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'fatal' at row 1
# 1406 (22001): Data too long for column 'fatal' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'fatal' at row 1
# 1406 (22001): Data too long for column 'fatal' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'fatal' at row 1
# 1406 (22001): Data too long for column 'fatal' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'fatal' at row 1
# 1054 (42S22): Unknown column 'nan' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'nan' in 'field list'
# 1406 (22001): Data too long for column 'fatal' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'fatal' at row 1
# 1406 (22001): Data too long for column 'fatal' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'fatal' at row 1
# 1406 (22001): Data too long for column 'fatal' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'fatal' at row 1
# 1406 (22001): Data too long for column 'fatal' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'fatal' at row 1
# 1406 (22001): Data too long for column 'fatal' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'fatal' at row 1
# 1054 (42S22): Unknown column 'nan' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'nan' in 'field list'
# 1406 (22001): Data too long for column 'fatal' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'fatal' at row 1
# 1406 (22001): Data too long for column 'fatal' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'fatal' at row 1
# 1406 (22001): Data too long for column 'fatal' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'fatal' at row 1
# 1406 (22001): Data too long for column 'fatal' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'fatal' at row 1
# 1406 (22001): Data too long for column 'fatal' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'fatal' at row 1
# 1406 (22001): Data too long for column 'fatal' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'fatal' at row 1
# 1406 (22001): Data too long for column 'fatal' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'fatal' at row 1
# 1406 (22001): Data too long for column 'fatal' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'fatal' at row 1
# 1406 (22001): Data too long for column 'fatal' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'fatal' at row 1
# 1406 (22001): Data too long for column 'fatal' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'fatal' at row 1
# 1406 (22001): Data too long for column 'fatal' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'fatal' at row 1
# 1406 (22001): Data too long for column 'fatal' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'fatal' at row 1
# 1406 (22001): Data too long for column 'fatal' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'fatal' at row 1
# 1406 (22001): Data too long for column 'fatal' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'fatal' at row 1
# 1406 (22001): Data too long for column 'fatal' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'fatal' at row 1
# 1406 (22001): Data too long for column 'fatal' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'fatal' at row 1
# 1406 (22001): Data too long for column 'fatal' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'fatal' at row 1
# 1406 (22001): Data too long for column 'fatal' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'fatal' at row 1
# 1406 (22001): Data too long for column 'fatal' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'fatal' at row 1
# 1406 (22001): Data too long for column 'fatal' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'fatal' at row 1
# 1406 (22001): Data too long for column 'fatal' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'fatal' at row 1
# 1406 (22001): Data too long for column 'fatal' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'fatal' at row 1
# 1406 (22001): Data too long for column 'fatal' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'fatal' at row 1
# 1406 (22001): Data too long for column 'fatal' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'fatal' at row 1
# 1406 (22001): Data too long for column 'fatal' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'fatal' at row 1
# 1406 (22001): Data too long for column 'fatal' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'fatal' at row 1
# 1406 (22001): Data too long for column 'fatal' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'fatal' at row 1
# 1406 (22001): Data too long for column 'fatal' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'fatal' at row 1
# 1406 (22001): Data too long for column 'fatal' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'fatal' at row 1
# 1406 (22001): Data too long for column 'fatal' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'fatal' at row 1
# 1406 (22001): Data too long for column 'fatal' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'fatal' at row 1
# 1406 (22001): Data too long for column 'fatal' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'fatal' at row 1
# 1406 (22001): Data too long for column 'fatal' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'fatal' at row 1
# 1406 (22001): Data too long for column 'fatal' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'fatal' at row 1
# 1406 (22001): Data too long for column 'fatal' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'fatal' at row 1
# 1406 (22001): Data too long for column 'fatal' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'fatal' at row 1
# 1406 (22001): Data too long for column 'fatal' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'fatal' at row 1
# 1406 (22001): Data too long for column 'fatal' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'fatal' at row 1
# 1406 (22001): Data too long for column 'fatal' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'fatal' at row 1
# 1406 (22001): Data too long for column 'fatal' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'fatal' at row 1
# 1406 (22001): Data too long for column 'fatal' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'fatal' at row 1
# 1406 (22001): Data too long for column 'fatal' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'fatal' at row 1
# 1406 (22001): Data too long for column 'fatal' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'fatal' at row 1
# 1406 (22001): Data too long for column 'fatal' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'fatal' at row 1
# 1406 (22001): Data too long for column 'fatal' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'fatal' at row 1
# 1406 (22001): Data too long for column 'fatal' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'fatal' at row 1
# 1406 (22001): Data too long for column 'fatal' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'fatal' at row 1
# 1406 (22001): Data too long for column 'fatal' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'fatal' at row 1
# 1406 (22001): Data too long for column 'fatal' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'fatal' at row 1
# 1406 (22001): Data too long for column 'fatal' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'fatal' at row 1
# 1406 (22001): Data too long for column 'fatal' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'fatal' at row 1
# 1406 (22001): Data too long for column 'fatal' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'fatal' at row 1
# 1406 (22001): Data too long for column 'fatal' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'fatal' at row 1
# 1406 (22001): Data too long for column 'fatal' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'fatal' at row 1
# 1406 (22001): Data too long for column 'fatal' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'fatal' at row 1
# 1406 (22001): Data too long for column 'fatal' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'fatal' at row 1
# 1406 (22001): Data too long for column 'fatal' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'fatal' at row 1
# 1406 (22001): Data too long for column 'fatal' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'fatal' at row 1
# 1406 (22001): Data too long for column 'fatal' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'fatal' at row 1
# 1406 (22001): Data too long for column 'fatal' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'fatal' at row 1
# 1406 (22001): Data too long for column 'fatal' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'fatal' at row 1
# 1406 (22001): Data too long for column 'fatal' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'fatal' at row 1
# 1406 (22001): Data too long for column 'fatal' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'fatal' at row 1
# 1406 (22001): Data too long for column 'fatal' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'fatal' at row 1
# 1406 (22001): Data too long for column 'fatal' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'fatal' at row 1
# 1406 (22001): Data too long for column 'fatal' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'fatal' at row 1
# 1406 (22001): Data too long for column 'fatal' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'fatal' at row 1
# 1406 (22001): Data too long for column 'fatal' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'fatal' at row 1
# 1406 (22001): Data too long for column 'fatal' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'fatal' at row 1
# 1406 (22001): Data too long for column 'fatal' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'fatal' at row 1
# 1406 (22001): Data too long for column 'fatal' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'fatal' at row 1
# 1406 (22001): Data too long for column 'fatal' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'fatal' at row 1
# 1406 (22001): Data too long for column 'fatal' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'fatal' at row 1
# 1406 (22001): Data too long for column 'fatal' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'fatal' at row 1
# 1406 (22001): Data too long for column 'fatal' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'fatal' at row 1
# 1406 (22001): Data too long for column 'fatal' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'fatal' at row 1
# 1406 (22001): Data too long for column 'fatal' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'fatal' at row 1
# 1406 (22001): Data too long for column 'fatal' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'fatal' at row 1
# 1406 (22001): Data too long for column 'fatal' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'fatal' at row 1
# 1406 (22001): Data too long for column 'fatal' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'fatal' at row 1
# 1406 (22001): Data too long for column 'fatal' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'fatal' at row 1
# 1406 (22001): Data too long for column 'fatal' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'fatal' at row 1
# 1406 (22001): Data too long for column 'fatal' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'fatal' at row 1
# 1406 (22001): Data too long for column 'fatal' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'fatal' at row 1
# 1406 (22001): Data too long for column 'fatal' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'fatal' at row 1
# 1406 (22001): Data too long for column 'fatal' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'fatal' at row 1
# 1406 (22001): Data too long for column 'fatal' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'fatal' at row 1
# 1406 (22001): Data too long for column 'fatal' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'fatal' at row 1
# 1406 (22001): Data too long for column 'fatal' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'fatal' at row 1
# 1406 (22001): Data too long for column 'fatal' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'fatal' at row 1
# 1406 (22001): Data too long for column 'fatal' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'fatal' at row 1
# 1406 (22001): Data too long for column 'fatal' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'fatal' at row 1
# 1406 (22001): Data too long for column 'fatal' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'fatal' at row 1
# 1406 (22001): Data too long for column 'fatal' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'fatal' at row 1
# 1406 (22001): Data too long for column 'fatal' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'fatal' at row 1
# 1406 (22001): Data too long for column 'fatal' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'fatal' at row 1
# 1406 (22001): Data too long for column 'fatal' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'fatal' at row 1
# 1406 (22001): Data too long for column 'fatal' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'fatal' at row 1
# 1406 (22001): Data too long for column 'fatal' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'fatal' at row 1
# 1406 (22001): Data too long for column 'fatal' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'fatal' at row 1
# 1406 (22001): Data too long for column 'fatal' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'fatal' at row 1
# 1406 (22001): Data too long for column 'fatal' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'fatal' at row 1
# 1406 (22001): Data too long for column 'fatal' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'fatal' at row 1
# 1406 (22001): Data too long for column 'fatal' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'fatal' at row 1
# 1406 (22001): Data too long for column 'fatal' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'fatal' at row 1
# 1406 (22001): Data too long for column 'fatal' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'fatal' at row 1
# 1406 (22001): Data too long for column 'fatal' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'fatal' at row 1
# 1406 (22001): Data too long for column 'fatal' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'fatal' at row 1
# 1406 (22001): Data too long for column 'fatal' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'fatal' at row 1
# 1406 (22001): Data too long for column 'fatal' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'fatal' at row 1
# 1406 (22001): Data too long for column 'fatal' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'fatal' at row 1
# 1406 (22001): Data too long for column 'fatal' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'fatal' at row 1
# 1406 (22001): Data too long for column 'fatal' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'fatal' at row 1
# 1406 (22001): Data too long for column 'fatal' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'fatal' at row 1
# 1406 (22001): Data too long for column 'fatal' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'fatal' at row 1
# 1406 (22001): Data too long for column 'fatal' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'fatal' at row 1
# 1406 (22001): Data too long for column 'fatal' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'fatal' at row 1
# 1406 (22001): Data too long for column 'fatal' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'fatal' at row 1
# 1406 (22001): Data too long for column 'fatal' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'fatal' at row 1
# 1406 (22001): Data too long for column 'fatal' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'fatal' at row 1
# 1406 (22001): Data too long for column 'fatal' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'fatal' at row 1
# 1406 (22001): Data too long for column 'fatal' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'fatal' at row 1
# 1406 (22001): Data too long for column 'fatal' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'fatal' at row 1
# 1406 (22001): Data too long for column 'fatal' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'fatal' at row 1
# 1406 (22001): Data too long for column 'fatal' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'fatal' at row 1
# 1406 (22001): Data too long for column 'fatal' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'fatal' at row 1
# 1406 (22001): Data too long for column 'fatal' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'fatal' at row 1
# 1406 (22001): Data too long for column 'fatal' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'fatal' at row 1
# 1406 (22001): Data too long for column 'fatal' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'fatal' at row 1
# 1406 (22001): Data too long for column 'fatal' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'fatal' at row 1
# 1406 (22001): Data too long for column 'fatal' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'fatal' at row 1
# 1406 (22001): Data too long for column 'fatal' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'fatal' at row 1
# 1406 (22001): Data too long for column 'fatal' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'fatal' at row 1
# 1406 (22001): Data too long for column 'fatal' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'fatal' at row 1
# 1406 (22001): Data too long for column 'fatal' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'fatal' at row 1
# 1406 (22001): Data too long for column 'fatal' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'fatal' at row 1
# 1406 (22001): Data too long for column 'fatal' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'fatal' at row 1
# 1406 (22001): Data too long for column 'fatal' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'fatal' at row 1
# 1406 (22001): Data too long for column 'fatal' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'fatal' at row 1
# 1406 (22001): Data too long for column 'fatal' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'fatal' at row 1
# 1406 (22001): Data too long for column 'fatal' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'fatal' at row 1
# 1406 (22001): Data too long for column 'fatal' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'fatal' at row 1
# 1406 (22001): Data too long for column 'fatal' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'fatal' at row 1
# 1406 (22001): Data too long for column 'fatal' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'fatal' at row 1
# 1406 (22001): Data too long for column 'fatal' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'fatal' at row 1
# 1406 (22001): Data too long for column 'fatal' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'fatal' at row 1
# 1406 (22001): Data too long for column 'fatal' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'fatal' at row 1
# 1406 (22001): Data too long for column 'fatal' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'fatal' at row 1
# 1406 (22001): Data too long for column 'fatal' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'fatal' at row 1
# 1406 (22001): Data too long for column 'fatal' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'fatal' at row 1
# 1406 (22001): Data too long for column 'fatal' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'fatal' at row 1
# 1406 (22001): Data too long for column 'fatal' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'fatal' at row 1
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_16086/158486214.py in <module>
#       4             VALUES ({fila["year"]}, "{fila['type']}", "{fila["country"]}","{fila["species_"]}", "{fila["fecha_limpia"]}","{fila["fatal"]}","{fila["sex"]}",{fila["latitud"]},{fila["longitud"]},{fila["age_NORM"]});
#       5             """
# ----> 6     crear_insertar_tabla("tiburones", "AlumnaAdalab", query_ataques)
#
# /tmp/ipykernel_16086/3835977145.py in crear_insertar_tabla(nombre_bbdd, contraseña, query)
#       1 def crear_insertar_tabla(nombre_bbdd, contraseña, query):
#       2     # nos conectamsos con el servidor usando el conector de sql
# ----> 3     cnx = mysql.connector.connect(user='root', password=f"{contraseña}",
#       4                                      host='127.0.0.1', database=f"{nombre_bbdd}")
#       5     # iniciamos el cursor
#
# ~/anaconda3/lib/python3.9/site-packages/mysql/connector/__init__.py in connect(*args, **kwargs)
#     270
#     271     if HAVE_CEXT and not use_pure:
# --> 272         return CMySQLConnection(*args, **kwargs)
#     273     return MySQLConnection(*args, **kwargs)
#     274 Connect = connect  # pylint: disable=C0103
#
# ~/anaconda3/lib/python3.9/site-packages/mysql/connector/connection_cext.py in __init__(self, **kwargs)
#      83
#      84         if kwargs:
# ---> 85             self.connect(**kwargs)
#      86
#      87     def _add_default_conn_attrs(self):
#
# ~/anaconda3/lib/python3.9/site-packages/mysql/connector/abstracts.py in connect(self, **kwargs)
#    1026
#    1027         self.disconnect()
# -> 1028         self._open_connection()
#    1029         # Server does not allow to run any other statement different from ALTER
#    1030         # when user's password has been expired.
#
# ~/anaconda3/lib/python3.9/site-packages/mysql/connector/connection_cext.py in _open_connection(self)
#     234
#     235         try:
# --> 236             self._cmysql.connect(**cnx_kwargs)
#     237             self._cmysql.converter_str_fallback = self._converter_str_fallback
#     238             if self.converter:
#
# KeyboardInterrupt:

# %%
for indice, fila in df_clima.iterrows():
    query_clima = f"""
            INSERT INTO clima (timepoint, cloudcover, temp2m, msl_pressure, `wind10m.direction`, `wind10m.speed`, pais, rh_950mb, wind_900mb)  
            VALUES ( {fila["timepoint"]}, {fila['cloudcover']}, {fila['temp2m']}, {fila['msl_pressure']}, {fila['wind10m.direction']}, {fila['wind10m.speed']}, "{fila['country']}", {fila['rh_950mb']}, {fila['wind_900mb']});
            """
    crear_insertar_tabla("tiburones","AlumnaAdalab", query_clima)
