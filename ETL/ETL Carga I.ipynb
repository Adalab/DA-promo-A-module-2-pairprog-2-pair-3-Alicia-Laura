# %%
import pandas as pd
import mysql.connector

# %%
df_attacks = pd.read_csv('attacks_limpieza_completa.csv', index_col=0)
df_attacks.head(2)
# Out:
#    year        type country   age     species_ fecha_limpia fatal sex  \
# 0  2018     Boating     usa  57.0  White shark          Jun     N   F
# 1  2018  Unprovoked     usa  11.0  Unespecific          Jun     N   F
#
#     latitud    longitud  ... fatal_N  fatal_Unknown  fatal_Y  fatal_N.1  \
# 0  39.78373 -100.445882  ...       1              0        0          1
# 1  39.78373 -100.445882  ...       1              0        0          1
#
#    fatal_Unknown.1  fatal_Y.1  species_.1  fecha_limpia.1  type.1  age_NORM
# 0                0          0           4               7       1  9.116327
# 1                0          0           3               7       7  3.804860
#
# [2 rows x 21 columns]

# %%
df_attacks = pd.read_csv('attacks_limpieza_completa.csv', index_col=0)
df_attacks.head(2)

# %%
df_clima = pd.read_csv('datos_clima.csv', index_col=0)
df_clima.head(2)
# Out:
#    timepoint  cloudcover  highcloud  midcloud  lowcloud  \
# 0          3           1      -9999     -9999     -9999
# 1          6           1      -9999     -9999     -9999
#
#                                           rh_profile  \
# 0  [{'layer': '950mb', 'rh': 4}, {'layer': '900mb...
# 1  [{'layer': '950mb', 'rh': 5}, {'layer': '900mb...
#
#                                         wind_profile  temp2m  lifted_index  \
# 0  [{'layer': '950mb', 'direction': 245, 'speed':...      22             2
# 1  [{'layer': '950mb', 'direction': 170, 'speed':...      22             2
#
#    rh2m  msl_pressure prec_type  prec_amount  snow_depth  wind10m.direction  \
# 0     5          1018      none            0           0                170
# 1     5          1018      none            0           0                155
#
#    wind10m.speed pais
# 0              2  usa
# 1              2  usa

# %% [markdown]
# Cread la BBDD con el nombre de tiburones.

# %%
def crear_bbdd(nombre_bbdd):

    mydb = mysql.connector.connect(
      host="localhost",
      user="root",
      password="AlumnaAdalab" 
    )
    print("Conexión realizada con éxito")
    
    mycursor = mydb.cursor()

    try:
        mycursor.execute(f"CREATE DATABASE IF NOT EXISTS {nombre_bbdd};")
        print(mycursor)
    except mysql.connector.Error as err:
        print(err)
        print("Error Code:", err.errno)
        print("SQLSTATE", err.sqlstate)
        print("Message", err.msg)

# %% [markdown]
# - Llamamos a la función con el nombre de nuestra BBDD y observamos que se ah creado.

# %%
mydb = crear_bbdd("tiburones")
# Out:
# Conexión realizada con éxito
# CMySQLCursor: CREATE DATABASE IF NOT EXISTS tiburones;

# %% [markdown]
# Cread las tablas de la BBDD:
# - Tabla ataques
# - Tabla clima

# %%
def crear_insertar_tabla(nombre_bbdd, contraseña, query):
    # nos conectamsos con el servidor usando el conector de sql
    cnx = mysql.connector.connect(user='root', password=f"{contraseña}",
                                     host='127.0.0.1', database=f"{nombre_bbdd}")
    # iniciamos el cursor
    mycursor = cnx.cursor()
    
    # intentamos hacer la query
    try: 
        mycursor.execute(query)
        cnx.commit() 
    # en caso de que podamos ejecutar la query devuelvenos un error para saber en que nos estamos equivocando
    except mysql.connector.Error as err:
        print(err)
        print("Error Code:", err.errno)
        print("SQLSTATE", err.sqlstate)
        print("Message", err.msg)

# %%
df_attacks.head(2)
# Out:
#    year        type country   age     species_ fecha_limpia fatal sex  \
# 0  2018     Boating     usa  57.0  White shark          Jun     N   F
# 1  2018  Unprovoked     usa  11.0  Unespecific          Jun     N   F
#
#     latitud    longitud  ... fatal_N  fatal_Unknown  fatal_Y  fatal_N.1  \
# 0  39.78373 -100.445882  ...       1              0        0          1
# 1  39.78373 -100.445882  ...       1              0        0          1
#
#    fatal_Unknown.1  fatal_Y.1  species_.1  fecha_limpia.1  type.1  age_NORM
# 0                0          0           4               7       1  9.116327
# 1                0          0           3               7       7  3.804860
#
# [2 rows x 21 columns]

# %%
tabla_ataques = '''
CREATE TABLA IF NOT EXISTS `tiburones`.`ataques`(
 `indice` INT NOT NULL AUTO_INCREMENT,
 `year` YEAR NOT NULL,
 `type` VARCHAR NOT NULL,
 `country` VARCHAR NOT NULL,
 `species_`, VARCHAR NOT NULL,
 `fecha_limpia` VARCHAR NOT NULL,
 `fatal` CHAR(1) NOT NULL,
 `sex` CHAR(1) NOT NULL,
 `latitud` FLOAT NOT NULL,
 `longitud` FLOAT NOT NULL,
 `age_NORM` FLOAT NOT NULL,
 PRIMARY KEY (`indice`))
ENGINE = InnoDB;
'''

# %%
df_clima.columns
# Out:
# Index(['timepoint', 'cloudcover', 'highcloud', 'midcloud', 'lowcloud',
#        'rh_profile', 'wind_profile', 'temp2m', 'lifted_index', 'rh2m',
#        'msl_pressure', 'prec_type', 'prec_amount', 'snow_depth',
#        'wind10m.direction', 'wind10m.speed', 'pais'],
#       dtype='object')

# %%
df_clima.head(2)
# Out:
#    timepoint  cloudcover  highcloud  midcloud  lowcloud  \
# 0          3           1      -9999     -9999     -9999
# 1          6           1      -9999     -9999     -9999
#
#                                           rh_profile  \
# 0  [{'layer': '950mb', 'rh': 4}, {'layer': '900mb...
# 1  [{'layer': '950mb', 'rh': 5}, {'layer': '900mb...
#
#                                         wind_profile  temp2m  lifted_index  \
# 0  [{'layer': '950mb', 'direction': 245, 'speed':...      22             2
# 1  [{'layer': '950mb', 'direction': 170, 'speed':...      22             2
#
#    rh2m  msl_pressure prec_type  prec_amount  snow_depth  wind10m.direction  \
# 0     5          1018      none            0           0                170
# 1     5          1018      none            0           0                155
#
#    wind10m.speed pais
# 0              2  usa
# 1              2  usa

# %%
tabla_clima = '''CREATE TABLA IF NOT EXISTS `tiburones`.`clima`(
 `indice` INT NOT NULL AUTO_INCREMENT,
 `timepoint` INT NOT NULL,
 `cloudcover` INT NOT NULL,
 `temp2m`, INT NOT NULL,
 `msl_pressure` INT NOT NULL,
 `wind10m.direction` INT NOT NULL,
 `wind10m.speed` INT NOT NULL,
 `pais` VARCHAR NOT NULL,
 PRIMARY KEY (`indice`))
ENGINE = InnoDB;
'''

# %% [markdown]
# - Creamos las tablas

# %%
crear_insertar_tabla("tiburones","admin", tabla_ataques)

# %%
crear_insertar_tabla("tiburones","admin", tabla_clima)

# %% [markdown]
# BONUS Insertar los datos en las tablas.
# 📌 Nota Esta parte del pair es optativa y no será considerada para la evaluación
